# %%
# !git clone  https://github.com/sniklaus/3d-ken-burns.git
# Out:
# Cloning into '3d-ken-burns'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 121 (delta 2), reused 6 (delta 2), pack-reused 115
# Receiving objects: 100% (121/121), 321.34 KiB | 14.61 MiB/s, done.
# Resolving deltas: 100% (70/70), done.

# %%
# downloading pretrained modesl
# !wget -O ./3d-ken-burns/models/disparity-estimation.pytorch http://content.sniklaus.com/kenburns/network-disparity.pytorch
# !wget -O ./3d-ken-burns/models/disparity-refinement.pytorch http://content.sniklaus.com/kenburns/network-refinement.pytorch
# !wget -O ./3d-ken-burns/models/pointcloud-inpainting.pytorch http://content.sniklaus.com/kenburns/network-inpainting.pytorch
# Out:
# --2020-06-12 06:04:27--  http://content.sniklaus.com/kenburns/network-disparity.pytorch
# Resolving content.sniklaus.com (content.sniklaus.com)... 88.198.95.97
# Connecting to content.sniklaus.com (content.sniklaus.com)|88.198.95.97|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 357438463 (341M) [application/octet-stream]
# Saving to: ‘./3d-ken-burns/models/disparity-estimation.pytorch’
#
# ./3d-ken-burns/mode 100%[===================>] 340.88M  15.4MB/s    in 21s
#
# 2020-06-12 06:04:49 (16.0 MB/s) - ‘./3d-ken-burns/models/disparity-estimation.pytorch’ saved [357438463/357438463]
#
# --2020-06-12 06:04:50--  http://content.sniklaus.com/kenburns/network-refinement.pytorch
# Resolving content.sniklaus.com (content.sniklaus.com)... 88.198.95.97
# Connecting to content.sniklaus.com (content.sniklaus.com)|88.198.95.97|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2438928 (2.3M) [application/octet-stream]
# Saving to: ‘./3d-ken-burns/models/disparity-refinement.pytorch’
#
# ./3d-ken-burns/mode 100%[===================>]   2.33M  2.32MB/s    in 1.0s
#
# 2020-06-12 06:04:51 (2.32 MB/s) - ‘./3d-ken-burns/models/disparity-refinement.pytorch’ saved [2438928/2438928]
#
# --2020-06-12 06:04:53--  http://content.sniklaus.com/kenburns/network-inpainting.pytorch
# Resolving content.sniklaus.com (content.sniklaus.com)... 88.198.95.97
# Connecting to content.sniklaus.com (content.sniklaus.com)|88.198.95.97|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33179067 (32M) [application/octet-stream]
# Saving to: ‘./3d-ken-burns/models/pointcloud-inpainting.pytorch’
#
# ./3d-ken-burns/mode 100%[===================>]  31.64M  11.1MB/s    in 2.9s
#
# 2020-06-12 06:04:56 (11.1 MB/s) - ‘./3d-ken-burns/models/pointcloud-inpainting.pytorch’ saved [33179067/33179067]

# %%
import chainer
chainer.print_runtime_info()
# Out:
# Platform: Linux-4.19.104+-x86_64-with-Ubuntu-18.04-bionic
# Chainer: 6.5.0
# ChainerX: Not Available
# NumPy: 1.18.5
# CuPy:
#   CuPy Version          : 6.5.0
#   CUDA Root             : /usr/local/cuda
#   CUDA Build Version    : 10010
#   CUDA Driver Version   : 10010
#   CUDA Runtime Version  : 10010
#   cuDNN Build Version   : 7603
#   cuDNN Version         : 7603
#   NCCL Build Version    : 2402
#   NCCL Runtime Version  : 2402
# iDeep: 2.0.0.post3

# %%
import os
os.environ['CUDA_HOME'] ="/usr/local/cuda"

# %%
# !pip install moviepy
# Out:
# Requirement already satisfied: moviepy in /usr/local/lib/python3.6/dist-packages (0.2.3.5)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.6/dist-packages (from moviepy) (4.41.1)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.6/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from moviepy) (1.18.5)
# Requirement already satisfied: imageio<3.0,>=2.1.2 in /usr/local/lib/python3.6/dist-packages (from moviepy) (2.4.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from imageio<3.0,>=2.1.2->moviepy) (7.0.0)

# %%
cd /content/3d-ken-burns
# Out:
# /content/3d-ken-burns

# %%
# uploading picture frim file system

from google.colab import files

uploaded = files.upload()
pic_name = list(uploaded.keys())[0]
print(pic_name)
# !mv ./$pic_name ./images/$pic_name
# Out:
#      <input type="file" id="files-385dbaea-849e-4f9f-99af-6bc1905b0048" name="files[]" multiple disabled />
#      <output id="result-385dbaea-849e-4f9f-99af-6bc1905b0048">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving aco.png to aco.png
# aco.png

# %%
# !pip install gevent
# !python autozoom.py --in ./images/$pic_name --out ./autozoom.mp4
# Out:
# Collecting gevent
#   Downloading https://files.pythonhosted.org/packages/28/8b/918c61f23693971f4eedb3f910438e18b9bab489511dd1f313657ef0a330/gevent-20.6.1-cp36-cp36m-manylinux2010_x86_64.whl (5.3MB)
#      |████████████████████████████████| 5.3MB 4.3MB/s
# Collecting zope.event
#   Downloading https://files.pythonhosted.org/packages/c5/96/361edb421a077a4c208b4a5c212737d78ae03ce67fbbcd01621c49f332d1/zope.event-4.4-py2.py3-none-any.whl
# Collecting greenlet>=0.4.16; platform_python_implementation == "CPython"
#   Downloading https://files.pythonhosted.org/packages/7e/a4/0d8685c98986326534b0753a8b92b3082bc9df42b348bc50d6c69839c9f9/greenlet-0.4.16-cp36-cp36m-manylinux1_x86_64.whl (44kB)
#      |████████████████████████████████| 51kB 6.9MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from gevent) (47.1.1)
# Collecting zope.interface
#   Downloading https://files.pythonhosted.org/packages/57/33/565274c28a11af60b7cfc0519d46bde4125fcd7d32ebc0a81b480d0e8da6/zope.interface-5.1.0-cp36-cp36m-manylinux2010_x86_64.whl (234kB)
#      |████████████████████████████████| 235kB 30.6MB/s
# Installing collected packages: zope.event, greenlet, zope.interface, gevent
# Successfully installed gevent-20.6.1 greenlet-0.4.16 zope.event-4.4 zope.interface-5.1.0
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.
# Downloading: "https://download.pytorch.org/models/vgg19_bn-c79401a0.pth" to /root/.cache/torch/checkpoints/vgg19_bn-c79401a0.pth
# 100% 548M/548M [00:08<00:00, 69.9MB/s]
# Downloading: "https://download.pytorch.org/models/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth" to /root/.cache/torch/checkpoints/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth
# 100% 170M/170M [00:03<00:00, 57.6MB/s]
# [MoviePy] >>>> Building video ./autozoom.mp4
# [MoviePy] Writing video ./autozoom.mp4
# 100% 150/150 [00:05<00:00, 27.62it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./autozoom.mp4

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('./autozoom.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=600 controls autoplay>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=600 controls autoplay>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %%
files.download("./autozoom.mp4")
